# %% [markdown]
# <a href="https://colab.research.google.com/github/Rxv3640/E-commerce-AI/blob/main/commerce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git add .
# !git commit -m "Added amazon reviews dataset."
# !git push origin main
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
